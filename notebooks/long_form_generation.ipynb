# %%
import os
import json

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %pip install nltk
# %pip install git+https://github.com/suno-ai/bark.git

from IPython.display import Audio
import nltk  # we'll use this to split into sentences
import numpy as np

from bark.generation import (
    generate_text_semantic,
    preload_models,
)
from bark.api import semantic_to_waveform
from bark import generate_audio, SAMPLE_RATE
# Out:
# Requirement already satisfied: nltk in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from nltk) (2023.3.23)
# Requirement already satisfied: tqdm in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from nltk) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/suno-ai/bark.git
#   Cloning https://github.com/suno-ai/bark.git to /tmp/pip-req-build-yobod_vn
#   Running command git clone --filter=blob:none --quiet https://github.com/suno-ai/bark.git /tmp/pip-req-build-yobod_vn
#   Resolved https://github.com/suno-ai/bark.git to commit 1ad007171e0c46078eb6d3afb6db4daf0c4f41cd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: boto3 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.26.130)
# Requirement already satisfied: encodec in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.1.1)
# Requirement already satisfied: funcy in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (2.0)
# Requirement already satisfied: huggingface-hub>=0.14.1 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.14.1)
# Requirement already satisfied: numpy in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.23.5)
# Requirement already satisfied: scipy in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.10.1)
# Requirement already satisfied: tokenizers in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.13.3)
# Requirement already satisfied: torch in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (2.0.1)
# Requirement already satisfied: tqdm in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (4.65.0)
# Requirement already satisfied: transformers in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (4.28.1)
# Requirement already satisfied: filelock in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.12.0)
# Requirement already satisfied: fsspec in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2023.4.0)
# Requirement already satisfied: requests in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2.29.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (23.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.130 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (1.29.130)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (0.6.1)
# Requirement already satisfied: torchaudio in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from encodec->suno-bark==0.0.1a0) (2.0.2)
# Requirement already satisfied: einops in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from encodec->suno-bark==0.0.1a0) (0.6.1)
# Requirement already satisfied: sympy in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (1.11.1)
# Requirement already satisfied: networkx in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (3.1)
# Requirement already satisfied: jinja2 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (2.0.0)
# Requirement already satisfied: setuptools in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->suno-bark==0.0.1a0) (65.5.0)
# Requirement already satisfied: wheel in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->suno-bark==0.0.1a0) (0.40.0)
# Requirement already satisfied: cmake in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from triton==2.0.0->torch->suno-bark==0.0.1a0) (3.26.3)
# Requirement already satisfied: lit in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from triton==2.0.0->torch->suno-bark==0.0.1a0) (16.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from transformers->suno-bark==0.0.1a0) (2023.3.23)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.130->boto3->suno-bark==0.0.1a0) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.130->boto3->suno-bark==0.0.1a0) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from jinja2->torch->suno-bark==0.0.1a0) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from sympy->torch->suno-bark==0.0.1a0) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/Python-3.10.9/jupyter/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.130->boto3->suno-bark==0.0.1a0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
preload_models()

# %%
import sys
print("Python version")
print (sys.version)
print("Version info.")
print (sys.version_info)

# Get the path of the active environment
env_path = os.environ['CONDA_PREFIX']

# Get the name of the active environment from the path
env_name = os.path.basename(env_path)

# Print the name of the active environment
print("Active conda environment:", env_name)

# Print the version of Python that is currently running
print("Python version:", sys.version)
# Out:
# Python version
# 3.10.9 (main, Apr 26 2023, 19:01:06) [GCC 11.3.0]
# Version info.
# sys.version_info(major=3, minor=10, micro=9, releaselevel='final', serial=0)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 8
#       5 print (sys.version_info)
#       7 # Get the path of the active environment
# ----> 8 env_path = os.environ['CONDA_PREFIX']
#      10 # Get the name of the active environment from the path
#      11 env_name = os.path.basename(env_path)
#
# File /usr/local/lib/python3.10/os.py:680, in _Environ.__getitem__(self, key)
#     677     value = self._data[self.encodekey(key)]
#     678 except KeyError:
#     679     # raise KeyError with the original key value
# --> 680     raise KeyError(key) from None
#     681 return self.decodevalue(value)
#
# KeyError: 'CONDA_PREFIX'

# %%
# Simple Long-Form Generation
# We split longer text into sentences using `nltk` and generate the sentences one by one.

# %%
script = """
Player Two is great, actually amazing. But do you know what's greater? 
You.
""".replace("\n", " ").strip()

# %%
nltk.download('punkt')
sentences = nltk.sent_tokenize(script)
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
SPEAKER = "v2/en_speaker_1"
silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence
print('sample rate', SAMPLE_RATE)
pieces = []
piecesJSON = []
for sentence in sentences:
    audio_array = generate_audio(sentence, history_prompt=SPEAKER)
    pieces += [audio_array, silence.copy()]
    piecesJSON += [audio_array.tolist(), silence.copy().tolist()]
    print('done', sentence, pieces)
    
with open('readme.txt', 'w') as f:
    json.dump(piecesJSON, f)

# %%
Audio(np.concatenate(pieces), rate=SAMPLE_RATE)

# %% [markdown]
# # $ \\ $

# %% [markdown]
# # Advanced Long-Form Generation
# Somtimes Bark will hallucinate a little extra audio at the end of the prompt.
# We can solve this issue by lowering the threshold for bark to stop generating text.
# We use the `min_eos_p` kwarg in `generate_text_semantic`

# %%
GEN_TEMP = 0.6
SPEAKER = "v2/en_speaker_9"
silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence

pieces = []
for sentence in sentences:
    semantic_tokens = generate_text_semantic(
        sentence,
        history_prompt=SPEAKER,
        temp=GEN_TEMP,
        min_eos_p=0.05,  # this controls how likely the generation is to end
    )

    audio_array = semantic_to_waveform(semantic_tokens, history_prompt=SPEAKER,)
    pieces += [audio_array, silence.copy()]
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 54.21it/s]
# 100%|██████████| 11/11 [00:05<00:00,  1.84it/s]
# 100%|██████████| 100/100 [00:01<00:00, 89.59it/s]
# 100%|██████████| 7/7 [00:03<00:00,  1.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 120.51it/s]
# 100%|██████████| 5/5 [00:02<00:00,  1.89it/s]

# %%
Audio(np.concatenate(pieces), rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # $ \\ $

# %% [markdown]
# # Make a Long-Form Dialog with Bark

# %% [markdown]
# ### Step 1: Format a script and speaker lookup

# %%
speaker_lookup = {"Samantha": "v2/en_speaker_9", "John": "v2/en_speaker_2"}

# Script generated by chat GPT
script = """
Samantha: Hey, have you heard about this new text-to-audio model called "Bark"?

John: No, I haven't. What's so special about it?

Samantha: Well, apparently it's the most realistic and natural-sounding text-to-audio model out there right now. People are saying it sounds just like a real person speaking.

John: Wow, that sounds amazing. How does it work?

Samantha: I think it uses advanced machine learning algorithms to analyze and understand the nuances of human speech, and then replicates those nuances in its own speech output.

John: That's pretty impressive. Do you think it could be used for things like audiobooks or podcasts?

Samantha: Definitely! In fact, I heard that some publishers are already starting to use Bark to create audiobooks. And I bet it would be great for podcasts too.

John: I can imagine. It would be like having your own personal voiceover artist.

Samantha: Exactly! I think Bark is going to be a game-changer in the world of text-to-audio technology."""
script = script.strip().split("\n")
script = [s.strip() for s in script if s]
script

# %% [markdown]
# ### Step 2: Generate the audio for every speaker turn

# %%
pieces = []
silence = np.zeros(int(0.5*SAMPLE_RATE))
for line in script:
    speaker, text = line.split(": ")
    audio_array = generate_audio(text, history_prompt=speaker_lookup[speaker], )
    pieces += [audio_array, silence.copy()]

# %% [markdown]
# ### Step 3: Concatenate all of the audio and play it

# %%
Audio(np.concatenate(pieces), rate=SAMPLE_RATE)
